# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhanTeruvai/Pandas-Numpy-Matplotlib/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict3={"Name":['Baron','Bharath','Balor','Bron','Bheeshma'],
       "Age":[26,22,30,35,37],
       "Salary(in LPA)":[5, 6, 4.5, 5.5, 6.5],
       "Experience(in Years)":[2, 3, 1.5, 2.2, 3.5],
       "Performance":["good","excellent","satisfactory","poor","excellent"]}
data = pd.DataFrame(dict3)
data
# Out:
#        Name  Age  Salary(in LPA)  Experience(in Years)   Performance
# 0     Baron   26             5.0                   2.0          good
# 1   Bharath   22             6.0                   3.0     excellent
# 2     Balor   30             4.5                   1.5  satisfactory
# 3      Bron   35             5.5                   2.2          poor
# 4  Bheeshma   37             6.5                   3.5     excellent

# %%
import pandas as pd
dict3={"Name":['Baron','Bharath','Balor','Bron','Bheeshma'],
       "Age":[26,22,30,35,37],
       "Salary(in LPA)":[5, 6, 4.5, 5.5, 6.5],
       "Experience(in Years)":[2, 3, 1.5, 2.2, 3.5],
       "Performance":["good","excellent","satisfactory","poor","excellent"]}
data = pd.DataFrame(dict3)
data.head(2)
# Out:
#       Name  Age  Salary(in LPA)  Experience(in Years) Performance
# 0    Baron   26             5.0                   2.0        good
# 1  Bharath   22             6.0                   3.0   excellent

# %%
import pandas as pd
dict3={"Name":['Baron','Bharath','Balor','Bron','Bheeshma'],
       "Age":[26,22,30,35,37],
       "Salary(in LPA)":[5, 6, 4.5, 5.5, 6.5],
       "Experience(in Years)":[2, 3, 1.5, 2.2, 3.5],
       "Performance":["good","excellent","satisfactory","poor","excellent"]}
data = pd.DataFrame(dict3)
data.tail(3)
# Out:
#        Name  Age  Salary(in LPA)  Experience(in Years)   Performance
# 2     Balor   30             4.5                   1.5  satisfactory
# 3      Bron   35             5.5                   2.2          poor
# 4  Bheeshma   37             6.5                   3.5     excellent

# %%
import pandas as pd
dict3={"Name":['Baron','Bharath','Balor','Bron','Bheeshma'],
       "Age":[26,22,30,35,37],
       "Salary(in LPA)":[5, 6, 4.5, 5.5, 6.5],
       "Experience(in Years)":[2, 3, 1.5, 2.2, 3.5],
       "Performance":["good","excellent","satisfactory","poor","excellent"]}
data = pd.DataFrame(dict3)
data.describe()
# Out:
#              Age  Salary(in LPA)  Experience(in Years)
# count   5.000000        5.000000              5.000000
# mean   30.000000        5.500000              2.440000
# std     6.204837        0.790569              0.801873
# min    22.000000        4.500000              1.500000
# 25%    26.000000        5.000000              2.000000
# 50%    30.000000        5.500000              2.200000
# 75%    35.000000        6.000000              3.000000
# max    37.000000        6.500000              3.500000
