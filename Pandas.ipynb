# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhanTeruvai/Pandas-Numpy-Matplotlib/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict1 = {"Name":['Priyang','Aadhya','Krisha','Vedant'],
        "marks": [96,95,97,90],
        "city":['Mumbai','Delhi','Pune','Nagpur']}
a = pd.DataFrame(dict1)
a
a.to_csv('friends.csv')
a.to_csv('friends.csv',index=False)
a.head(2)
# Out:
#       Name  marks    city
# 0  Priyang     96  Mumbai
# 1   Aadhya     95   Delhi

# %%
import pandas as pd
dict1 = {"Name":['Priyang','Aadhya','Krisha','Vedant'],
        "marks": [96,95,97,90],
        "city":['Mumbai','Delhi','Pune','Nagpur']}
a = pd.DataFrame(dict1)
a
a.to_csv('friends.csv')
a.to_csv('friends.csv',index=False)
a.tail(2)
# Out:
#      Name  marks    city
# 2  Krisha     97    Pune
# 3  Vedant     90  Nagpur

# %%
import pandas as pd
dict1 = {"Name":['Priyang','Aadhya','Krisha','Vedant'],
        "marks": [96,95,97,90],
        "city":['Mumbai','Delhi','Pune','Nagpur']}
a = pd.DataFrame(dict1)
a
a.describe()
# Out:
#            marks
# count   4.000000
# mean   94.500000
# std     3.109126
# min    90.000000
# 25%    93.750000
# 50%    95.500000
# 75%    96.250000
# max    97.000000
