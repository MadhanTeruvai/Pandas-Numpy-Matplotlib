# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhanTeruvai/Pandas-Numpy-Matplotlib/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict2={"Name":['Akash','Azad','Arjun','Akhil','Amar'],
"Marks":[79,95,92,89,34],
"Grades":['B','S','S','A','F']}
Result = pd.DataFrame(dict2)
Result.head(2)
# Out:
#     Name  Marks Grades
# 0  Akash     79      B
# 1   Azad     95      S

# %%
import pandas as pd
dict2={"Name":['Akash','Azad','Arjun','Akhil','Amar'],
"Marks":[79,95,92,89,34],
"Grades":['B','S','S','A','F']}
Result = pd.DataFrame(dict2)
Result.head(3)
# Out:
#     Name  Marks Grades
# 0  Akash     79      B
# 1   Azad     95      S
# 2  Arjun     92      S

# %%
import pandas as pd
dict2={"Name":['Akash','Azad','Arjun','Akhil','Amar'],
"Marks":[79,95,92,89,34],
"Grades":['B','S','S','A','F']}
Result = pd.DataFrame(dict2)
Result.tail(2)
# Out:
#     Name  Marks Grades
# 3  Akhil     89      A
# 4   Amar     34      F

# %%
import pandas as pd
dict2={"Name":['Akash','Azad','Arjun','Akhil','Amar'],
"Marks":[79,95,92,89,34],
"Grades":['B','S','S','A','F']}
Result = pd.DataFrame(dict2)
Result.describe()
# Out:
#            Marks
# count   5.000000
# mean   77.800000
# std    25.213092
# min    34.000000
# 25%    79.000000
# 50%    89.000000
# 75%    92.000000
# max    95.000000
