# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhanTeruvai/Pandas-Numpy-Matplotlib/blob/main/pandas%3D4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python doesn't support "array"
# bcz it has list with same capability
# we can use with numpy
import pandas as pd
dict1={"name": ["apple", "moto", "samsung", "vivo", "oneplus", "oppo"],
       "my_ratings": [9.5, 9, 9.5, 8, 8.5, 8],
       "madein": ["US", "china", "south korea", "china", "china", "china"]}
pd.DataFrame(dict1)
# Out:
#       name  my_ratings       madein
# 0    apple         9.5           US
# 1     moto         9.0        china
# 2  samsung         9.5  south korea
# 3     vivo         8.0        china
# 4  oneplus         8.5        china
# 5     oppo         8.0        china

# %%
import pandas as pd
dict1={"name": ["apple", "moto", "samsung", "vivo", "oneplus", "oppo"],
       "my_ratings": [9.5, 9, 9.5, 8, 8.5, 8],
       "madein": ["US", "china", "south korea", "china", "china", "china"]}
data=pd.DataFrame(dict1)
data.head(3)
# Out:
#       name  my_ratings       madein
# 0    apple         9.5           US
# 1     moto         9.0        china
# 2  samsung         9.5  south korea

# %%
import pandas as pd
dict1={"name": ["apple", "moto", "samsung", "vivo", "oneplus", "oppo"],
       "my_ratings": [9.5, 9, 9.5, 8, 8.5, 8],
       "madein": ["US", "china", "south korea", "china", "china", "china"]}
data=pd.DataFrame(dict1)
data.tail(3)
# Out:
#       name  my_ratings madein
# 3     vivo         8.0  china
# 4  oneplus         8.5  china
# 5     oppo         8.0  china

# %%
import pandas as pd
dict1={"name": ["apple", "moto", "samsung", "vivo", "oneplus", "oppo"],
       "my_ratings": [9.5, 9, 9.5, 8, 8.5, 8],
       "madein": ["US", "china", "south korea", "china", "china", "china"]}
data=pd.DataFrame(dict1)
data.describe()
# Out:
#        my_ratings
# count    6.000000
# mean     8.750000
# std      0.689202
# min      8.000000
# 25%      8.125000
# 50%      8.750000
# 75%      9.375000
# max      9.500000
